# %% [markdown]
# <div style="background-color:#f9fafb; padding:20px; margin-bottom:15px">
#   <h1 style="color:#08519c; font-size:32px; margin:0"><div align="center"> Capstone Project</h1>
#   <h2 style="color:#023047; font-size:30px; margin-top:5px"><div align="center">"From Data to Dollars: Understanding Salary Determinants"</h2>
# </div>
#
# <hr style="height:3px;border:none;color:#0891b2;background-color:#0891b2;" />
#
# <div style="background-color:#ffffff; padding:15px; border:2px solid #0891b2; border-radius:6px; margin-top:15px">
#   <h3 style="color:#08519c; margin-top:0">🎯 Project Objective</h3>
#   <p>This project explores how factors such as
#   <b style="color:#08519c">job title</b>,
#   <b style="color:#08519c">years of experience</b>,
#   <b style="color:#08519c">education level</b>,
#   <b style="color:#08519c">skills</b>,
#   <b style="color:#08519c">industry</b>,
#   <b style="color:#08519c">company size</b>,
#   <b style="color:#08519c">certifications</b>, and
#   <b style="color:#08519c">remote work</b> influence salary outcomes.</p>
# </div>
#
# <div style="background-color:#edf5ff; padding:15px; border-left:6px solid #0891b2; border-radius:5px; margin-top:20px">
#   <h3 style="color:#08519c; margin-top:0">📑 Table of Contents</h3>
#   <p>1️⃣ Load the dataset
#
# 2️⃣ Initial overview (structure)
# 🧾 Summary of Initial Overview (Pre‑Cleaning)
#
# 3️⃣ Data Pre-processing (missing values, encoding, features)
# 🧾 Summary of Data Pre‑processing
#
# 4️⃣ Exploratory analysis (patterns, correlations, trends)
# 🧾 Final EDA Summary
#
# 5️⃣ Visualizations (clear, recruiter‑ready charts)
#
# 6️⃣ Insights & conclusions</p>
#
# </div>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <div style="background-color:#deebf7; padding:12px; border-left:6px solid #0891b2; border-radius:4px; margin-top:15px">
#   <h3 style="color:#08519c; margin:0">1. Dataset Loading</h3>
# </div>

# %%
data= pd.read_csv("Job Salary Prediction.csv")

# %% [markdown]
# <div style="background-color:#deebf7; padding:12px; border-left:6px solid #0891b2; border-radius:4px; margin-top:15px">
#   <h3 style="color:#08519c; margin:0">2. Initial Overview</h3>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">2.1 Number of Rows and Columns</h4>
# </div>

# %%
rows, columns= data.shape
print(f"The dataset contains {rows} rows and {columns} columns.\n")
# Out:
# The dataset contains 250194 rows and 10 columns.

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">2.2 Column names</h4>
# </div>

# %%
print(data.columns)
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary'],
#       dtype='object')

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">2.3 Data types of each column</h4>
# </div>

# %%
print("\nData types:")
print (data.dtypes)
# Out:
# Data types:
# job_title            object
# experience_years    float64
# education_level      object
# skills_count        float64
# industry             object
# company_size         object
# location             object
# remote_work          object
# certifications      float64
# salary                int64
# dtype: object

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">2.4 Dataset Structure and Basic Checks</h4>
# </div>

# %%
data.head()
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer              10.0        Bachelor           NaN
# 1        Data Analyst               5.0        Bachelor          17.0
# 2  Frontend Developer              18.0             PhD           4.0
# 3    Business Analyst              19.0             PhD          13.0
# 4     Product Manager              15.0        Bachelor           7.0
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid             2.0  109413
# 1        Telecom        Small  Australia          No             0.0   93764
# 2          Media          NaN  Singapore          No             1.0  148123
# 3         Retail       Medium     Canada         Yes             0.0  189123
# 4  Manufacturing        Large     Sweden         Yes             0.0  165069

# %%
data.tail()
# Out:
#                 job_title  experience_years education_level  skills_count  \
# 250189   Business Analyst              17.0          Master           2.0
# 250190        AI Engineer              16.0          Master          14.0
# 250191  Software Engineer              16.0             PhD          18.0
# 250192   Business Analyst              18.0        Bachelor           5.0
# 250193     Data Scientist              13.0         Diploma          17.0
#
#           industry company_size     location remote_work  certifications  \
# 250189      Retail       Medium  Netherlands          No             3.0
# 250190  Healthcare      Startup           UK      Hybrid             4.0
# 250191   Education        Small    Australia      Hybrid             3.0
# 250192  Technology        Small       Sweden         Yes             1.0
# 250193     Telecom        Small           UK      Hybrid             0.0
#
#         salary
# 250189  139419
# 250190  194819
# 250191  156195
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250194 entries, 0 to 250193
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_title         250194 non-null  object
#  1   experience_years  250192 non-null  float64
#  2   education_level   250175 non-null  object
#  3   skills_count      250193 non-null  float64
#  4   industry          250187 non-null  object
#  5   company_size      250175 non-null  object
#  6   location          250181 non-null  object
#  7   remote_work       250191 non-null  object
#  8   certifications    250168 non-null  float64
#  9   salary            250194 non-null  int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 19.1+ MB
# None

# %%
print("\nSummery statistics:")
data.describe()
# Out:
# Summery statistics:
#        experience_years   skills_count  certifications         salary
# count     250192.000000  250193.000000   250168.000000  250194.000000
# mean          10.005092       9.997742        2.491885  145716.230825
# std            6.060777       5.479552        1.706366   37407.830337
# min            0.000000       1.000000        0.000000   31867.000000
# 25%            5.000000       5.000000        1.000000  119356.000000
# 50%           10.000000      10.000000        2.000000  143452.500000
# 75%           15.000000      15.000000        4.000000  169491.750000
# max           20.000000      19.000000        5.000000  333046.000000

# %% [markdown]
# <div style="background-color:#f7fbff; padding:15px; border:2px solid #0891b2; border-radius:6px; margin-top:15px">
#   <h3 style="color:#08519c; margin-top:0">🧾Summary of Initial Overview (Pre‑Cleaning)</h3>
#   <ul>
#     <li><b>Dataset size:</b> 250,194 rows × 10 columns</li>
#     <li><b>Data types:</b> 6 categorical, 4 numerical</li>
#     <li><b>Missing values:</b> Minor gaps in predictors, salary complete</li>
#     <li><b>Key findings:</b>
#       <ul>
#         <li>Experience averages ~10 years (0–20)</li>
#         <li>Skills count averages ~10 (1–19)</li>
#         <li>Certifications mostly 2–3 (0–5)</li>
#         <li>Salary mean ~145K, ranging from ~31K to ~333K</li>
#       </ul>
#     </li>
#     <li><b>Overall:</b> Large, well‑structured dataset with slight missing data and wide salary variation</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color:#deebf7; padding:12px; border-left:6px solid #0891b2; border-radius:4px; margin-top:15px">
#   <h3 style="color:#08519c; margin:0">3. Data Pre-processing</h3>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">3.1  Handling missing values</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>Checking Missing Values:

# %%
print(data.isnull().sum())
# Out:
# job_title            0
# experience_years     2
# education_level     19
# skills_count         1
# industry             7
# company_size        19
# location            13
# remote_work          3
# certifications      26
# salary               0
# dtype: int64

# %% [markdown]
# ##### <font color='#0891b2'>For Numerical columns Handling missing values using Median:

# %%
data['experience_years'] = data['experience_years'].fillna(data['experience_years'].median())

data['skills_count']     = data['skills_count'].fillna(data['skills_count'].median())

data['certifications']   = data['certifications'].fillna(data['certifications'].median())

# %% [markdown]
# ##### <font color='#0891b2'>For Categorical columns Handling missing values using Mode:

# %%
data['education_level']  = data['education_level'].fillna(data['education_level'].mode()[0])

data['industry']         = data['industry'].fillna(data['industry'].mode()[0])

data['company_size']     = data['company_size'].fillna(data['company_size'].mode()[0])

data['location']         = data['location'].fillna(data['location'].mode()[0])

data['remote_work']      = data['remote_work'].fillna(data['remote_work'].mode()[0])

# %% [markdown]
# ##### <font color='#0891b2'>Checking missing values are resolved:

# %%
print("Missing values after handling:\n", data.isnull().sum())
# Out:
# Missing values after handling:
#  job_title           0
# experience_years    0
# education_level     0
# skills_count        0
# industry            0
# company_size        0
# location            0
# remote_work         0
# certifications      0
# salary              0
# dtype: int64

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">3.2  Removing Duplicates</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>checking for duplicate rows:

# %%
duplicates_count= data.duplicated().sum()
print("Number of duplicate rows:",duplicates_count)
# Out:
# Number of duplicate rows: 194

# %% [markdown]
# ##### <font color='#0891b2'>Removing duplicate rows:

# %%
data=data.drop_duplicates()

# %% [markdown]
# ##### <font color='#0891b2'>Checking duplicate values resolved:

# %%
duplicates_count= data.duplicated().sum()
print("Number of duplicate rows:",duplicates_count)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">3.3  Correcting data types </h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>Converting numerical columns to integers:

# %%
data['experience_years'] = data['experience_years'].astype('int64')
data['skills_count']     = data['skills_count'].astype('int64')
data['certifications']   = data['certifications'].astype('int64')

# %% [markdown]
# ##### <font color='#0891b2'>Converting categorical columns to 'category':

# %%
categorical_cols = ['job_title', 'education_level', 'industry',
                    'company_size', 'location', 'remote_work']

for col in categorical_cols:
    data[col] = data[col].astype('category')

# %% [markdown]
# ##### <font color='#0891b2'>Verifying changes:

# %%
print(data.dtypes)
# Out:
# job_title           category
# experience_years       int64
# education_level     category
# skills_count           int64
# industry            category
# company_size        category
# location            category
# remote_work         category
# certifications         int64
# salary                 int64
# dtype: object

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">3.4  Creating derived columns</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>Experience group

# %%
data['experience_group'] = pd.cut(
    data['experience_years'],
    bins=[0,5,10,15,20],
    labels=['Junior','Mid','Senior','Expert'])

# %% [markdown]
# ##### <font color='#0891b2'>Skill level

# %%
data['skill_level'] = pd.cut(
    data['skills_count'],
    bins=[0,5,10,15,20],
    labels=['Low','Medium','High','Very High'])

# %% [markdown]
# ##### <font color='#0891b2'>Certification Status

# %%
data['has_certification'] = (data['certifications'] > 0).astype(int)

# %% [markdown]
# ##### <font color='#0891b2'>Work Mode

# %%
data['work_mode'] = data['remote_work'].map({
    'Yes': 'Remote',
    'No': 'On-Site',
    'Hybrid': 'Hybrid'
})

# %% [markdown]
# ##### <font color='#0891b2'>Salary band

# %%
data['salary_band'] = pd.cut(
    data['salary'],
    bins=[0,100000,150000,200000,350000],
    labels=['Low','Mid','High','Very High'])

# %% [markdown]
# ##### <font color='#0891b2'>Verifying New columns added:

# %%
print(data.columns)
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary', 'experience_group', 'skill_level', 'has_certification',
#        'work_mode', 'salary_band'],
#       dtype='object')

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">3.5  Filtering and aggregating data</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>Aggregating: count of employees by job title

# %%
job_counts = data['job_title'].value_counts()

print(job_counts)
# Out:
# job_title
# Backend Developer            21125
# Cybersecurity Analyst        20959
# Product Manager              20950
# AI Engineer                  20945
# Data Scientist               20890
# DevOps Engineer              20889
# Software Engineer            20876
# Data Analyst                 20722
# Cloud Engineer               20686
# Machine Learning Engineer    20677
# Business Analyst             20648
# Frontend Developer           20633
# Name: count, dtype: int64

# %% [markdown]
# ##### <font color='#0891b2'>Average salary by education level

# %%
edu_salary = data.groupby('education_level', observed=False)['salary'].mean().round(2)
print(edu_salary)
# Out:
# education_level
# Bachelor       142410.66
# Diploma        137160.31
# High School    131715.56
# Master         153299.45
# PhD            163975.93
# Name: salary, dtype: float64

# %%
data_cleaned= data.copy()

# %% [markdown]
# ### <font color='#08519c'> Final Data Preview </font>
# <hr style="height:1.75px;border:none;color:#08519c;background-color:#08519c;" />
#
# After completing all preprocessing steps (cleaning, type corrections, derived columns, filtering, aggregation), here’s the updated dataset:

# %%
data_cleaned.head()
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor            10
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary  \
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media        Small  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069
#
#   experience_group skill_level  has_certification work_mode salary_band
# ...

# %%
rows, columns= data_cleaned.shape
print(f"The dataset contains {rows} rows and {columns} columns.\n")
# Out:
# The dataset contains 250000 rows and 15 columns.

# %% [markdown]
# <div style="background-color:#f7fbff; padding:15px; border:2px solid #0891b2; border-radius:6px; margin-top:15px">
#   <h3 style="color:#08519c; margin-top:0">🧾 Summary of Data Pre‑processing</h3>
#   <ul>
#     <li><b> Cleaning:</b> Filled missing values with median; removed duplicates</li>
#     <li><b> New Features:</b> Salary range category, experience bracket</li>
#     <li><b> Filtering & Aggregation:</b> Employee counts by job title; average salary by education</li>
#     <li><b> Current Dataset:</b> 250,000 rows × 16 columns</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color:#deebf7; padding:12px; border-left:6px solid #0891b2; border-radius:4px; margin-top:15px">
#   <h3 style="color:#08519c; margin:0">4. Exploratory Data Analysis (EDA)</h3>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.1   Statistical Summaries</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'> Salary Summary

# %%
salary_summary = data_cleaned['salary'].describe().round(2).to_frame().rename(columns={'salary':'Salary'})
salary_summary
# Out:
#           Salary
# count  250000.00
# mean   145718.08
# std     37407.95
# min     31867.00
# 25%    119358.00
# 50%    143453.00
# 75%    169492.00
# max    333046.00

# %% [markdown]
# ##### <font color='#0891b2'> Experience Summary

# %%
experience_summary = data_cleaned['experience_years'].describe().round(2).to_frame().rename(columns={'experience_years':'Experience (Years)'})
experience_summary
# Out:
#        Experience (Years)
# count           250000.00
# mean                10.01
# std                  6.06
# min                  0.00
# 25%                  5.00
# 50%                 10.00
# 75%                 15.00
# max                 20.00

# %% [markdown]
# ##### <font color='#0891b2'>  Certifications Summary

# %%
cert_summary = data_cleaned['certifications'].describe().round(2).to_frame().rename(columns={'certifications':'Certifications'})
cert_summary
# Out:
#        Certifications
# count       250000.00
# mean             2.49
# std              1.71
# min              0.00
# 25%              1.00
# 50%              2.00
# 75%              4.00
# max              5.00

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Statistical Summaries</h4>
#   <ul>
#     <li><b> Salary:</b> Avg ≈ 145.7k, range 31.8k–333k, moderate spread</li>
#     <li><b> Experience:</b> Avg ≈ 10 years, balanced distribution (0–20)</li>
#     <li><b> Certifications:</b> Avg ≈ 2.5, most hold 1–4</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.2   Univariate Analysis</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>  Job Title Counts

# %%
job_title_counts = data_cleaned['job_title'].value_counts().to_frame().rename(columns={'job_title':'Count'})
job_title_counts
# Out:
#                            count
# job_title
# Backend Developer          21125
# Cybersecurity Analyst      20959
# Product Manager            20950
# AI Engineer                20945
# Data Scientist             20890
# DevOps Engineer            20889
# Software Engineer          20876
# Data Analyst               20722
# Cloud Engineer             20686
# Machine Learning Engineer  20677
# Business Analyst           20648
# Frontend Developer         20633

# %%
print("Most common job title:", data_cleaned['job_title'].mode()[0])
# Out:
# Most common job title: Backend Developer

# %% [markdown]
# ##### <font color='#0891b2'> Education Level Counts

# %%
edu_counts = data_cleaned['education_level'].value_counts().to_frame().rename(columns={'education_level':'Count'})
edu_counts
# Out:
#                  count
# education_level
# Master           50369
# High School      50062
# Bachelor         49942
# PhD              49855
# Diploma          49772

# %%
print("Most common education level:", data_cleaned['education_level'].mode()[0])
# Out:
# Most common education level: Master

# %% [markdown]
# ##### <font color='#0891b2'> Company Size Counts

# %%
company_counts = data_cleaned['company_size'].value_counts().to_frame().rename(columns={'company_size':'Count'})
company_counts
# Out:
#               count
# company_size
# Large         50253
# Small         50243
# Medium        50022
# Enterprise    49874
# Startup       49608

# %% [markdown]
# ##### <font color='#0891b2'>  Industry Counts

# %%
industry_counts = data_cleaned['industry'].value_counts().to_frame().rename(columns={'industry':'Count'})
industry_counts
# Out:
#                count
# industry
# Finance        25397
# Consulting     25258
# Media          25034
# Manufacturing  25024
# Technology     24903
# Government     24900
# Healthcare     24897
# Education      24887
# Telecom        24859
# Retail         24841

# %% [markdown]
# ##### <font color='#0891b2'>  Remote Work Counts

# %%
remote_counts = data_cleaned['remote_work'].value_counts().to_frame().rename(columns={'work_mode':'Count'})
remote_counts
# Out:
#              count
# remote_work
# No           83623
# Hybrid       83476
# Yes          82901

# %% [markdown]
# ##### <font color='#0891b2'>  Skewness & kurtosis

# %%
skewness_kurtosis = pd.DataFrame({
    "Metric": ["Skewness", "Kurtosis"],
    "Salary": [data_cleaned['salary'].skew().round(2), data_cleaned['salary'].kurt().round(2)],
})
skewness_kurtosis
# Out:
#      Metric  Salary
# 0  Skewness    0.38
# 1  Kurtosis    0.15

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Univariate Analysis</h4>
#   <ul>
#     <li><b> Job Titles:</b> Balanced distribution across roles; top counts include Backend Developer (21,125), Cybersecurity Analyst (20,959), Product Manager (20,950), AI Engineer (20,945), and Data Scientist (20,890).</li>
#     <li><b> Education Levels:</b> Even spread — Master (50,369), High School (50,062), Bachelor (49,942), PhD (49,855), Diploma (49,772).</li>
#     <li><b> Company Size:</b> Nearly equal representation — Large (50,253), Small (50,243), Medium (50,022), Enterprise (49,874), Startup (49,608).</li>
#     <li><b> Industry:</b> Broad coverage — Finance (25,397), Consulting (25,258), Media (25,034), Manufacturing (25,024), Technology (24,903), Government (24,900), Healthcare (24,897), Education (24,887), Telecom (24,859), Retail (24,841).</li>
#     <li><b> Remote Work:</b> Well balanced — No (83,623), Hybrid (83,476), Yes (82,901).</li>
#     <li><b> Salary Distribution:</b> Skewness ≈ 0.38 (slightly right‑skewed), Kurtosis ≈ 0.15 (near normal).</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.3  Bivariate Analysis</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'> Salary by Location

# %%
location_salary = (
    data_cleaned.groupby('location', observed=True)['salary']
    .mean()
    .round(2)
    .reset_index())
location_salary
# Out:
#       location     salary
# 0    Australia  139359.64
# 1       Canada  167392.81
# 2      Germany  153376.90
# 3        India   97689.44
# 4  Netherlands  139296.33
# 5       Remote  139442.53
# 6    Singapore  139341.52
# 7       Sweden  139439.60
# 8           UK  160075.14
# 9          USA  181716.30

# %% [markdown]
# ##### <font color='#0891b2'> Salary vs Experience

# %%
exp_salary = data_cleaned.groupby('experience_years')['salary'].mean().round(2).reset_index()


exp_salary.columns = ['Experience (Years)', 'Average Salary']

exp_salary
# Out:
#     Experience (Years)  Average Salary
# 0                    0       118872.62
# 1                    1       121250.53
# 2                    2       124228.94
# 3                    3       126921.60
# 4                    4       129688.78
# 5                    5       131789.42
# 6                    6       134900.10
# 7                    7       137560.81
# 8                    8       140667.76
# 9                    9       142763.83
# 10                  10       145765.87
# 11                  11       148133.17
# 12                  12       150779.03
# 13                  13       154082.62
# 14                  14       156413.15
# 15                  15       158981.14
# 16                  16       162290.87
# 17                  17       164282.18
# 18                  18       167421.19
# 19                  19       169797.36
# 20                  20       173179.71

# %% [markdown]
# ##### <font color='#0891b2'> Salary by Education

# %%
edu_salary = (
    data_cleaned.groupby('education_level', observed=True)['salary']
    .mean()
    .round(2)
    .reset_index()
)
edu_salary.columns = ['Education Level', 'Average Salary']
edu_salary
# Out:
#   Education Level  Average Salary
# 0        Bachelor       142410.66
# 1         Diploma       137160.31
# 2     High School       131715.56
# 3          Master       153299.45
# 4             PhD       163975.93

# %% [markdown]
# ##### <font color='#0891b2'>Salary by Job Title

# %%
job_salary = (
    data_cleaned.groupby('job_title', observed=True)['salary']
    .mean()
    .round(2)
    .reset_index()
)
job_salary.columns = ['Job Title', 'Average Salary']
job_salary
# Out:
#                     Job Title  Average Salary
# 0                 AI Engineer       173498.48
# 1           Backend Developer       139202.77
# 2            Business Analyst       122551.23
# 3              Cloud Engineer       152102.54
# 4       Cybersecurity Analyst       148697.70
# 5                Data Analyst       119891.70
# 6              Data Scientist       147258.21
# 7             DevOps Engineer       149959.27
# 8          Frontend Developer       132653.84
# 9   Machine Learning Engineer       163022.50
# 10            Product Manager       157594.93
# 11          Software Engineer       141739.52

# %% [markdown]
# ##### <font color='#0891b2'>Work mode vs. Salary

# %%
workmode_salary = (
    data_cleaned.groupby('work_mode', observed=True)['salary']
    .mean()
    .round(2)
    .reset_index())

workmode_salary.columns = ['Work Mode', 'Average Salary']

workmode_salary
# Out:
#   Work Mode  Average Salary
# 0    Hybrid       143969.90
# 1   On-Site       143932.98
# 2    Remote       149279.03

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Bivariate Analysis</h4>
#   <ul>
#     <li><b> Salary by Location:</b> USA highest (≈182k), Canada (≈167k), UK (≈160k). India lowest (~97k). Other regions cluster ~139–153k.</li>
#     <li><b> Experience ↔ Salary:</b> Clear upward trend (0 yrs ≈119k → 20 yrs ≈173k).</li>
#     <li><b> Education ↔ Salary:</b> Higher education = higher pay (PhD ≈164k > Master ≈153k > Bachelor ≈142k).</li>
#     <li><b> Job Title ↔ Salary:</b> AI/ML Engineers & Product Managers earn most; Analysts lowest.</li>
#     <li><b> Work Mode ↔ Salary:</b> Remote (≈149k) slightly higher than Hybrid/On‑Site (≈144k).</li>
#     <li><b> Education × Job Title:</b> Salary rises consistently with education across roles.</li>
#     <li><b> Skills × Certifications:</b> More skills/certifications add incremental salary value.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.4  Multivariate Analysis</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>Salary by Education Level and Job Title

# %%
pivot_table = pd.pivot_table(
    data_cleaned,
    values='salary',
    index='education_level',
    columns='job_title',
    aggfunc='mean',
    observed=True  
).round(2)

pivot_table
# Out:
# job_title        AI Engineer  Backend Developer  Business Analyst  \
# education_level
# Bachelor           170325.17          136614.18         118766.76
# Diploma            164761.71          130268.43         114286.84
# High School        159405.10          125820.04         108162.53
# Master             181457.90          146400.80         130107.86
# PhD                191769.17          157716.07         141037.63
#
# job_title        Cloud Engineer  Cybersecurity Analyst  Data Analyst  \
# education_level
# Bachelor              148710.52              145168.03     116165.02
# Diploma               143830.07              140348.92     111354.09
# High School           138073.94              134647.77     105992.61
# Master                160326.73              156340.15     127658.59
# PhD                   170478.57              166825.40     138094.79
#
# job_title        Data Scientist  DevOps Engineer  Frontend Developer  \
# education_level
# ...

# %% [markdown]
# ##### <font color='#0891b2'>Salary by Skills Count and Certifications

# %%
skills_cert_salary = (
    data_cleaned.groupby(['skills_count','certifications'], observed=True)['salary']
    .mean()
    .round(2)
    .reset_index()
)

skills_cert_salary.columns = ['Skills Count', 'Certifications', 'Average Salary']
skills_cert_salary.head(10)
# Out:
#    Skills Count  Certifications  Average Salary
# 0             1               0       133722.35
# 1             1               1       135186.18
# 2             1               2       137264.09
# 3             1               3       138128.64
# 4             1               4       140584.20
# 5             1               5       141853.22
# 6             2               0       136438.34
# 7             2               1       135514.64
# 8             2               2       136678.35
# 9             2               3       140140.30

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Multivariate Analysis</h4>
#   <ul>
#     <li><b> Education × Job Title:</b> Salary increases consistently with higher education across all roles. PhD holders earn the most (e.g., AI Engineer ≈192k, Product Manager ≈176k).</li>
#     <li><b> Skills × Certifications:</b> More skills and certifications generally increase salary, though the effect size is moderate.</li>
#     <li><b> Combined Insights:</b> Multivariate pivots confirm that education level, job role, and certifications together shape salary outcomes more strongly than any single factor.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.5 GroupBy Analysis</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2'>Salary by Location × Work Mode

# %%
pivot_loc_work = pd.pivot_table(
    data_cleaned,
    values='salary',
    index='location',
    columns='work_mode',
    aggfunc='mean',
    observed=True   
).round(2)

pivot_loc_work
# Out:
# work_mode       Hybrid    On-Site     Remote
# location
# Australia    137251.79  137465.06  143317.12
# Canada       165893.47  164682.18  171652.78
# Germany      151941.14  151274.05  156992.14
# India         97000.23   96113.39   99985.77
# Netherlands  137361.16  137252.50  143270.56
# Remote       137963.33  137652.77  142696.77
# Singapore    137603.34  137573.23  142848.89
# Sweden       137612.08  137760.66  142991.87
# UK           158197.65  158730.72  163410.17
# USA          179000.78  180303.39  185847.24

# %% [markdown]
# ##### <font color='#0891b2'>Salary by Industry

# %%
industry_salary = (
    data_cleaned.groupby('industry', observed=True)['salary']
    .max()
    .round(2)
    .reset_index())

industry_salary.columns = ['Industry', 'Highest Salary']
industry_salary
# Out:
#         Industry  Highest Salary
# 0     Consulting          333046
# 1      Education          317497
# 2        Finance          314829
# 3     Government          328616
# 4     Healthcare          317377
# 5  Manufacturing          327025
# 6          Media          309091
# 7         Retail          321127
# 8     Technology          327217
# 9        Telecom          324583

# %% [markdown]
# #####  <font color='#0891b2' >Salary by Company Size (Company Size Effect)

# %%
company_salary = (
    data_cleaned.groupby('company_size', observed=True)['salary']
    .mean()
    .round(2)
    .reset_index())

company_salary.columns = ['Company Size', 'Average Salary']

company_salary
# Out:
#   Company Size  Average Salary
# 0   Enterprise       169615.19
# 1        Large       155711.31
# 2       Medium       141538.12
# 3        Small       134359.32
# 4      Startup       127288.68

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of GroupBy Analysis</h4>
#   <ul>
#     <li><b> Industry (Max Salary):</b> Consulting (≈333k) and Government (≈329k) top the list.</li>
#     <li><b> Company Size (Avg Salary):</b> Enterprise (≈170k) > Large (≈156k) > Startup (≈127k).</li>
#     <li><b> Location × Work Mode:</b>
#       <ul>
#         <li>USA highest across all modes (Remote ≈186k).</li>
#         <li>Canada & UK: Remote roles earn a clear premium.</li>
#         <li>Germany: Mid‑range, Remote slightly higher.</li>
#         <li>India: Lowest overall, Remote adds only small uplift.</li>
#         <li>Other regions: Cluster ~137–143k, Remote consistently higher.</li>
#       </ul>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.6 Pivot Table Analysis</h4>
# </div>

# %% [markdown]
# ##### <font color='#0891b2' > Salary comparison across Work Mode and Industry

# %%
pivot_work_industry = pd.pivot_table(
    data_cleaned,
    values='salary',
    index='work_mode',
    columns='industry',
    aggfunc='max',
    observed=True  ).round(2)
pivot_work_industry = pivot_work_industry.reset_index()

pivot_work_industry
# Out:
# industry work_mode  Consulting  Education  Finance  Government  Healthcare  \
# 0           Hybrid      309957     303397   305434      297218      313157
# 1          On-Site      295760     315928   292855      328616      297906
# 2           Remote      333046     317497   314829      306036      317377
#
# industry  Manufacturing   Media  Retail  Technology  Telecom
# 0                327025  309091  298656      327217   308911
# 1                325052  308894  296787      284500   323985
# 2                295943  305515  321127      300764   324583

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Pivot Table Analysis</h4>
#   <ul>
#     <li><b> Work Mode × Industry:</b> Remote roles often reach the highest ceilings (e.g., Consulting ≈333k).</li>
#     <li><b> Technology & Manufacturing:</b> Consistently strong salary performance across all work modes.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.7 Correlation Analysis</h4>
# </div>

# %%
corr_matrix = data_cleaned.corr(numeric_only=True).round(2)

plt.figure(figsize=(5,4))
sns.heatmap(
    corr_matrix,
    annot=True,        
    cmap="YlGnBu",     
    fmt=".2f",         
    linewidths=0.5)

plt.title("Correlation Matrix Heatmap", fontsize=14, pad=12)
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Correlation Analysis</h4>
#   <ul>
#     <li><b> Experience ↔ Salary:</b> Moderate positive correlation (≈0.44).</li>
#     <li><b> Has Certification ↔ Salary:</b> Moderate correlation (≈0.51).</li>
#     <li><b> Certifications ↔ Has Certification:</b> Strong logical link (≈0.66).</li>
#     <li><b> Skills & Remote Flag ↔ Salary:</b> Weak correlations (≈0.13 and ≈0.07).</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">4.8 Outlier Detection</h4>
# </div>

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(x=data_cleaned['salary'],color="#21918C")
plt.title("Salary Outlier Detection", color="#0A0A0A", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:12px; border-radius:6px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">📊 Summary of Outlier Detection</h4>
#   <ul>
#     <li><b> Salary Boxplot:</b> Median ≈143k, Interquartile Range (IQR) ~119k–169k.</li>
#     <li><b> Outliers:</b> Values above ~250k, with extreme salaries reaching up to ≈333k.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color:#f7fbff; padding:15px; border:2px solid #0891b2; border-radius:6px; margin-top:15px">
#   <h3 style="color:#08519c; margin-top:0">🧾 Final EDA Summary</h3>
#   <ul>
#     <li><b> Experience:</b> Strongest driver of salary outcomes.</li>
#     <li><b> Education:</b> Significant boost, especially PhD/Master levels.</li>
#     <li><b> Job Title & Company Size:</b> Major differentiators in pay.</li>
#     <li><b> Industry:</b> Maxima vary, but averages remain flatter.</li>
#     <li><b> Remote Work:</b> Offers a slight premium across regions.</li>
#     <li><b> Certifications & Skills:</b> Add incremental value, but less impactful than experience or education.</li>
#     <li><b> Outliers:</b> Present at the high end, but do not distort overall trends.</li>
#     <li><b> Correlation Matrix:</b> Confirms logical relationships among predictors.</li>
#     <li><b> Location:</b> Critical factor — USA/Canada/UK lead, India lowest, Remote amplifies regional differences.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color:#deebf7; padding:12px; border-left:6px solid #0891b2; border-radius:4px; margin-top:15px">
#   <h3 style="color:#08519c; margin:0">5.  Visualizations</h3>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Section 1: Roles & Job Titles</h4>
# </div>

# %% [markdown]
# #### <font color='#0891b2' > 1. Average Salary by Job Title
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This chart highlights how salaries differ across job titles.

# %%
custom_palette = [ "#46327E", "#3F4788", "#365C8D", "#2E6E8E", 
                   "#277F8E", "#21918C", "#1FA187", "#2DB27D", 
                   "#4AC16D", "#73D056", "#A0DA39", "#D0E11C"] 

# Average salary by job title
job_salary = data.groupby('job_title', observed=False)['salary'].mean().reset_index()
job_salary = job_salary.sort_values('salary', ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x='job_title', y='salary', hue='job_title',
            data=job_salary, palette=custom_palette, legend=False)

plt.title("Average Salary by Job Title", fontsize=14, color='#111842', weight='bold')
plt.xticks(rotation=40, fontsize=10, color='#333333')
plt.xlabel("Job Title", fontsize=12, color='#333333')
plt.ylabel("Average Salary (USD)", fontsize=12, color='#333333')

# Adding labels
for index, row in job_salary.iterrows():
    plt.text(index, row.salary + 1500, f"{int(row.salary):,}",
             ha='center', fontsize=9, color='#333333')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     AI Engineers and Machine Learning Engineers lead salary averages, while Data Analysts and Business Analysts earn comparatively less.
#   </p>
# </div>

# %% [markdown]
# #### <font color='#0891b2' > 2. Salary Spread by Job Title
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This boxplot shows the variation in salaries within each job title.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='job_title', y='salary', hue='job_title',
            data=data, palette=custom_palette, legend=False)

plt.title("Salary Spread by Job Title", fontsize=14, color='#111842', weight='bold')
plt.xticks(rotation=40, fontsize=10, color='#333333')
plt.xlabel("Job Title", fontsize=12, color='#333333')
plt.ylabel("Salary (USD)", fontsize=12, color='#333333')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     AI Engineers and Machine Learning Engineers show the highest median salaries, with wide spreads indicating strong earning potential at senior levels.
#     In contrast, Data Analysts and Business Analysts have lower medians and narrower ranges, reflecting more consistent but modest pay scales.
#   </p>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Section 2: Education & Role Interaction</h4>
# </div>

# %% [markdown]
# #### <font color='#0891b2' > 3. Salary Distribution by Education Level
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This violin plot shows how salaries vary across education levels.

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x='education_level', y='salary', data=data,
               hue='education_level',
               palette=["#46327E", "#2E6E8E", "#1FA187", "#A0DA39", "#D0E11C"],
               legend=False)

plt.title("Salary Distribution by Education Level", fontsize=14, color='#111842', weight='bold')
plt.xlabel("Education Level", fontsize=12, color='#333333')
plt.ylabel("Salary (USD)", fontsize=12, color='#333333')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Salaries generally increase with higher education levels, with Master's and PhD holders showing the strongest earning potential.
#   </p>
# </div>

# %% [markdown]
# #### <font color='#0891b2' > 4. Salary by Education × Job Title
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This set of boxplots compares salaries by education level within each job title.

# %%
g = sns.catplot(x="education_level", y="salary", col="job_title",
                data=data, kind="box", col_wrap=3,
                hue="education_level", palette=["#46327E", "#2E6E8E", "#1FA187", "#A0DA39", "#D0E11C"], legend=False)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Salary by Education × Job Title", fontsize=14, color='#111842', weight='bold')
for ax in g.axes.flat:
    ax.set_title(ax.get_title(), color="#21918C", fontsize=12, weight='bold')
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Across all job titles, higher education consistently leads to higher salaries, with Master's and PhD holders earning more than those with Bachelor's, Diploma, or High School qualifications.
#     The effect is visible in both technical and non‑technical roles, confirming that education level is a strong driver of compensation across the board.
#   </p>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Section 3: Career Growth Factors</h4>
# </div>

# %% [markdown]
# #### <font color='#0891b2' > 5. Salary Trend by Years of Experience
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This line chart shows how average salary grows with more years of experience.

# %%
exp_salary = data_cleaned[['experience_years', 'salary']]

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='experience_years', y='salary',
             data=exp_salary,
             color="#21918C",   
             linewidth=2, marker="o")

plt.title("Salary Trend by Years of Experience", fontsize=14, color='#111842', weight='bold')
plt.xlabel("Years of Experience", fontsize=12, color='#333333')
plt.ylabel("Average Salary (USD)", fontsize=12, color='#333333')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Salaries increase steadily with years of experience, showing a clear positive correlation between professional tenure and compensation.
#     The upward trend highlights the strong value of long-term expertise, with significant gains after 10+ years in the field.
#   </p>
# </div>

# %% [markdown]
# #### <font color='#0891b2' >6. Average Salary vs Skills Count
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This chart shows how salary changes with the number of skills.

# %%
# Group by skills_count and calculate average salary
skills_avg = data.groupby('skills_count', observed=False)['salary'].mean().reset_index()

plt.figure(figsize=(10,5))
sns.lineplot(x='skills_count', y='salary', data=skills_avg,
             color="#21918C", linewidth=2, marker="o", label="Skills")

plt.title("Average Salary vs Skills Count", fontsize=14, color='#111842', weight='bold')
plt.xlabel("Number of Skills", fontsize=12, color='#333333')
plt.ylabel("Average Salary (USD)", fontsize=12, color='#333333')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Average salary rises as the number of skills increases, showing a clear positive correlation between skill acquisition and earning potential.
#     Professionals with a broader skill set consistently command higher pay, emphasizing the importance of continuous learning and diversification.
#   </p>
# </div>

# %% [markdown]
# #### <font color='#0891b2' >7. Average Salary vs Certifications Count
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This chart shows how certifications impact average salary.

# %%
# Group by certifications_count and calculate average salary
certs_avg = data.groupby('certifications', observed=False)['salary'].mean().reset_index()

plt.figure(figsize=(10,5))
sns.lineplot(x='certifications', y='salary', data=certs_avg,
             color="#21918C", linewidth=2, marker="o", label="Certifications")

plt.title("Average Salary vs Certifications Count", fontsize=14, color='#111842', weight='bold')
plt.xlabel("Number of Certifications", fontsize=12, color='#333333')
plt.ylabel("Average Salary (USD)", fontsize=12, color='#333333')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Average salary increases with the number of certifications, showing a clear positive correlation between professional credentials and compensation.
#     Even a small number of certifications provides a measurable boost, while multiple certifications strengthen earning potential further.
#   </p>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Section 4: Industry & Company Context</h4>
# </div>

# %% [markdown]
# #### <font color='#0891b2' >8. Average vs Max Salary by Industry
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This chart compares average and maximum salaries across industries.

# %%
industry_stats = data.groupby('industry', observed=False)['salary'].agg(
    average_salary='mean',
    max_salary='max'
).reset_index()

# %%
x = np.arange(len(industry_stats['industry']))  # positions
width = 0.35  # bar width

plt.figure(figsize=(10,5))

# Average salary bars
plt.bar(x - width/2, industry_stats['average_salary'], width,
        color="#A0DA39", label="Average Salary")

# Max salary bars
plt.bar(x + width/2, industry_stats['max_salary'], width,
        color="#1FA187", label="Max Salary")

# Titles and labels
plt.title("Average vs Max Salary by Industry", fontsize=14, color='#111842', weight='bold')
plt.xlabel("Industry", fontsize=12, color='#333333')
plt.ylabel("Salary (USD)", fontsize=12, color='#333333')
plt.xticks(x, industry_stats['industry'], rotation=45, ha='right', color='#333333')
plt.yticks(color='#333333')
plt.legend()

# Add value labels
for i, val in enumerate(industry_stats['average_salary']):
    plt.text(i - width/2, val + 2000, f"{int(val):,}", ha='center', fontsize=9, color='#333333')
for i, val in enumerate(industry_stats['max_salary']):
    plt.text(i + width/2, val + 2000, f"{int(val):,}", ha='center', fontsize=9, color='#333333')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Across industries, average salaries remain fairly consistent, but maximum salaries vary widely, revealing significant earning potential in certain sectors.
#     Consulting, Government, Technology, and Manufacturing show the highest maximum salaries, highlighting opportunities for top performers to earn well above the industry average.
#   </p>
# </div>

# %% [markdown]
# #### <font color='#0891b2' >9. Average Salary by Company Size
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This chart shows how company size influences average salary.

# %%
plt.figure(figsize=(10,5))
sns.pointplot(
    x='company_size', y='salary', hue='company_size',
    data=data,
    palette=["#46327E", "#2E6E8E", "#1FA187", "#A0DA39", "#D0E11C"],
    dodge=False,
    markers='o',          
    linestyles='',       
    legend=False
)

plt.setp(plt.gca().lines, markersize=12)   
plt.setp(plt.gca().collections, sizes=[200])            
plt.title("Average Salary by Company Size", fontsize=14, color='#111842', weight='bold')
plt.xlabel("Company Size", fontsize=12, color='#333333')
plt.ylabel("Average Salary (USD)", fontsize=12, color='#333333')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Larger companies consistently offer higher average salaries, with Enterprise organizations leading compensation levels.
#     Startups and small companies provide lower pay on average.
#   </p>
# </div>

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Section 5: Work Mode & Location</h4></h4>
# </div>

# %% [markdown]
# #### <font color='#0891b2' >10. Salary by Work Mode across Locations
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This set of barplots compares salaries by work mode within each location.

# %%
g = sns.catplot(
    x='work_mode', y='salary',
    hue='work_mode',               
    col='location', col_wrap=5,  
    data=data, kind='bar',        
    palette=["#2E6E8E", "#1FA187", "#A0DA39"], 
    height=4, aspect=1,
    legend=False                    
)

g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Salary by Work Mode across Locations", fontsize=14, color='#111842', weight='bold')

# Customize subplot titles
for ax in g.axes.flat:
    ax.set_title(ax.get_title(), color="#9A243F", fontsize=12, weight='bold')

plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     Remote work consistently offers the highest salaries across most locations, reflecting global demand for flexible talent.
#     On‑site and hybrid roles show lower averages, though regional differences highlight how location still influences compensation levels.
#   </p>
# </div>

# %% [markdown]
# #### <font color='#0891b2' >11. Average Salary Share by Location
#
# <hr style="height:2px;border:none;color:#21918C;background-color:#21918C;" />
#
# ##### This pie chart shows the proportion of average salaries across locations.

# %%
location_stats = data.groupby('location', observed=False)['salary'].mean().reset_index()

# %%
plt.figure(figsize=(12,7))
plt.pie(location_stats['salary'],
        labels=location_stats['location'],
        autopct='%1.1f%%',
        colors=sns.color_palette(["#365C8D", "#2E6E8E", 
                   "#277F8E", "#21918C", "#1FA187", "#2DB27D", 
                   "#4AC16D", "#73D056", "#A0DA39", "#D0E11C"], len(location_stats)),
        startangle=140)

plt.title("Average Salary Share by Location", fontsize=14, color='#111842', weight='bold')
plt.show()

# %% [markdown]
# <div style="border:2px solid #08519c; padding:8px; border-radius:4px; margin-top:10px">
#   <h4 style="color:#08519c; margin:0">Insight:</h4>
#   <p style="margin:0">
#     The USA, Canada, and UK contribute the largest shares of average salary, reflecting strong compensation markets in these regions.
#     Other locations such as Sweden, Singapore, Netherlands, and Australia hold balanced mid‑range shares, while India shows a smaller proportion, highlighting regional disparities in salary distribution.
#   </p>
# </div>

# %% [markdown]
# <div style="background-color:#deebf7; padding:12px; border-left:6px solid #0891b2; border-radius:4px; margin-top:15px">
#   <h3 style="color:#08519c; margin:0"> 6. Insight Generation and Report</h3>
# </div>

# %% [markdown]
# <!-- Key Patterns -->
# <div style="background-color:#edf5ff; padding:15px; border-left:6px solid #0891b2; border-radius:5px; margin-top:20px">
#   <h3 style="color:#08519c; margin-top:0">🔎 Key Patterns and Correlations</h3>
#   <p>Several clear patterns emerged from the analysis:</p>
#   <ul style="margin:0; padding-left:20px">
#     <li><b style="color:#08519c">Education:</b> Higher degrees consistently lead to better pay. Master’s and PhD holders earn noticeably more across almost every role.</li>
#     <li><b style="color:#08519c">Experience:</b> Salaries climb steadily with years of work. The biggest jumps appear after 10+ years, showing the value of long‑term expertise.</li>
#     <li><b style="color:#08519c">Skills & Certifications:</b> Professionals who keep learning and adding certifications see stronger salaries. Upskilling clearly pays off.</li>
#     <li><b style="color:#08519c">Industry:</b> Average salaries look similar across industries, but the top earners in Consulting, Government, Technology, and Manufacturing reach much higher levels.</li>
#     <li><b style="color:#08519c">Company Size:</b> Larger firms consistently offer better pay, while smaller companies and startups provide lower averages but often more growth opportunities.</li>
#     <li><b style="color:#08519c">Work Mode:</b> Remote roles stand out with the highest salaries, reflecting global demand for flexible talent.</li>
#     <li><b style="color:#08519c">Location:</b> The USA, Canada, and UK dominate salary share, while India shows lower averages despite strong talent pools.</li>
#   </ul>
# </div>
#
# <!-- Significant Insights -->
# <div style="background-color:#f9fcff; padding:15px; border-left:6px solid #0891b2; border-radius:5px; margin-top:20px">
#   <h3 style="color:#08519c; margin-top:0">💡 Significant Insights</h3>
#   <ul style="margin:0; padding-left:20px">
#     <li><b>Education matters everywhere:</b> Advanced degrees boost pay across all job titles, not just technical ones.</li>
#     <li><b>Upskilling pays off:</b> Adding more skills and certifications directly translates into higher compensation.</li>
#     <li><b>Experience pays steadily:</b> Salaries rise consistently with tenure, with significant gains after 10+ years of experience.</li>
#     <li><b>Remote work premium:</b> Remote positions consistently outpace hybrid and on‑site roles in salary.</li>
#     <li><b>Industry ceiling effect:</b> While averages are similar, certain industries allow standout performers to earn far above the norm.</li>
#     <li><b>Company size advantage:</b> Enterprise firms lead in pay, reinforcing the stability and resources of larger organizations.</li>
#   </ul>
# </div>
#
# <!-- Overall Summary -->
# <div style="background-color:#ffffff; padding:15px; border:2px solid #0891b2; border-radius:6px; margin-top:25px">
#   <h3 style="color:#08519c; margin-top:0">📌 Overall Summary</h3>
#   <p>Education, experience, skills, certifications, company size, work mode, and location all play a major role in shaping salaries. The strongest drivers are higher education, continuous upskilling, and remote work opportunities, while industry and company size set the ceiling for top earners.</p>
# </div>
#
# <!-- Recommendations -->
# <div style="background-color:#edf5ff; padding:15px; border-left:6px solid #0891b2; border-radius:5px; margin-top:20px">
#   <h3 style="color:#08519c; margin-top:0">🚀 Recommendations / Next Steps</h3>
#   <ul style="margin:0; padding-left:20px">
#     <li><b>For professionals:</b> Invest in advanced degrees, certifications, and continuous skill development to maximize earning potential.</li>
#     <li><b>For recruiters/companies:</b> Emphasize remote flexibility and upskilling opportunities to attract top talent.</li>
#   </ul>
# </div>
